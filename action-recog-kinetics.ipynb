# %%
# Cell 1: Clone the repo
# !git clone https://github.com/wagur1/pre_processing_simulate /kaggle/working/repo
# %cd /kaggle/working/repo
# Out:
# Cloning into '/kaggle/working/repo'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 73 (delta 35), reused 46 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 7.68 MiB | 24.80 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /kaggle/working/repo

# %%
# !python train.py --dataset-mode kaggle_kinetics400 --kaggle --epochs 50 --resume /kaggle/input/preprocessing-checkpoint-ep18/checkpoints/best_model.pt
# Out:
# [INFO] Kaggle environment detected — applying Kaggle defaults
# [INFO] Reduced num_workers to 2 for Kaggle
# [INFO] Using device: cuda
# [INFO] Mode: kaggle_kinetics400 (slug='kinetics-train-5per')
# [INFO] Detected video folder format at: /kaggle/input/datasets/rohanmallick/kinetics-train-5per/kinetics400_5per/kinetics400_5per/train
# [INFO] KaggleKinetics400: 10805 videos, 400 classes from '/kaggle/input/datasets/rohanmallick/kinetics-train-5per/kinetics400_5per/kinetics400_5per/train'
# [INFO] Train samples: 8484, Test samples: 2321
# [INFO] Detected 400 classes
# Downloading: "https://download.pytorch.org/models/r3d_18-b3b3357e.pth" to /root/.cache/torch/hub/checkpoints/r3d_18-b3b3357e.pth
# 100%|█████████████████████████████████████████| 127M/127M [00:00<00:00, 188MB/s]
# [INFO] Analyzer loaded and frozen (0/62 params trainable)
# [INFO] Adam optimizer — lr=0.0001, trainable params: 356,377
# ...
