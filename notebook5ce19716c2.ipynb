# %%
# !pip install compressai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.5/444.5 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# ...

# %%
# !git clone https://github.com/wagur1/pre_processing_simulate /kaggle/working/repo
# %cd /kaggle/working/repo
# Out:
# Cloning into '/kaggle/working/repo'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 107 (delta 54), reused 64 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 15.27 MiB | 29.01 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /kaggle/working/repo

# %%
# !python -u train.py \
    --dataset-mode kaggle_kinetics400 \
    --kaggle \
    --epochs 50 \
    --codec-type compressai
# Out:
# [INFO] Kaggle environment detected — applying Kaggle defaults
# [INFO] Reduced num_workers to 2 for Kaggle
# [INFO] Using device: cuda
# [INFO] Mode: kaggle_kinetics400 (slug='kinetics-train-5per')
# Traceback (most recent call last):
#   File "/kaggle/working/repo/train.py", line 694, in <module>
#     main()
#   File "/kaggle/working/repo/train.py", line 514, in main
#     train_dataset, test_dataset, num_classes = build_kaggle_kinetics400_splits(
#                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/repo/dataset.py", line 1251, in build_kaggle_kinetics400_splits
#     raise RuntimeError(
# RuntimeError: Kaggle dataset not found at '/kaggle/input/kinetics-train-5per'.
# Make sure you've added the dataset 'kinetics-train-5per' to your Kaggle notebook.
# Directory structure of /kaggle/input:
# Empty or not found

# %%
# !python -u visualize.py \
    --test-dir /kaggle/input/datasets/rohanmallick/kinetics-train-5per/kinetics400_5per/kinetics400_5per/test \
    --preprocessor-weights /kaggle/working/checkpoints/best_model.pt \
    --codec-type compressai \
    --qp 40 \
    --output /kaggle/working/visualization.png
# Out:
# [INFO] Using device: cuda
# Traceback (most recent call last):
#   File "/kaggle/working/repo/visualize.py", line 155, in <module>
#     main()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/repo/visualize.py", line 79, in main
#     _, test_ds, _ = build_kaggle_kinetics400_splits(os.path.dirname(args.test_dir), args.test_dir, num_frames=16)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/repo/dataset.py", line 1251, in build_kaggle_kinetics400_splits
#     raise RuntimeError(
# RuntimeError: Kaggle dataset not found at '/kaggle/input/datasets/rohanmallick/kinetics-train-5per/kinetics400_5per/kinetics400_5per'.
# ...

# %%
# !python -u eval_real_codec.py \
    --test-dir /kaggle/input/datasets/rohanmallick/kinetics-train-5per/kinetics400_5per/kinetics400_5per/test \
    --preprocessor-weights /kaggle/working/checkpoints/best_model.pt \
    --codec-type compressai \
    --codec both
# Out:
# usage: eval_real_codec.py [-h] --test-dir TEST_DIR --preprocessor-weights
#                           PREPROCESSOR_WEIGHTS [--codec {h264,h265,both}]
#                           [--batch-size BATCH_SIZE] [--limit LIMIT]
# eval_real_codec.py: error: unrecognized arguments: --codec-type compressai
