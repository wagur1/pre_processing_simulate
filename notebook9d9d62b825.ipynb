# %% [markdown]
# <a href="https://www.kaggle.com/code/wagur124705/notebook9d9d62b825?scriptVersionId=334839712" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Cell 1: Clone the repo
# !git clone https://github.com/wagur1/pre_processing_simulate /kaggle/working/repo
# %cd /kaggle/working/repo
# Out:
# Cloning into '/kaggle/working/repo'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 15), reused 32 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 7.67 MiB | 36.19 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /kaggle/working/repo

# %%
# !python train.py --dataset-mode kaggle_got10k --kaggle --epochs 50
# Out:
# [INFO] Kaggle environment detected — applying Kaggle defaults
# [INFO] Reduced num_workers to 2 for Kaggle
# [INFO] Using device: cuda
# [INFO] Mode: kaggle_got10k (slug='got10k')
# [INFO] Kaggle GOT-10k paths resolved:
# [INFO]   Train: /kaggle/input/datasets/abhimanyukarshni/got10k/val
# [INFO]   Test : /kaggle/input/datasets/abhimanyukarshni/got10k/test
# [INFO] GOT-10k: train=180 sequences (/kaggle/input/datasets/abhimanyukarshni/got10k/val), test=180 sequences (/kaggle/input/datasets/abhimanyukarshni/got10k/test), 20 pseudo-classes
# [INFO] Train samples: 180, Test samples: 180
# [INFO] Detected 20 classes
# Downloading: "https://download.pytorch.org/models/r3d_18-b3b3357e.pth" to /root/.cache/torch/hub/checkpoints/r3d_18-b3b3357e.pth
# 100%|█████████████████████████████████████████| 127M/127M [00:00<00:00, 226MB/s]
# [INFO] Analyzer loaded and frozen (0/62 params trainable)
# [INFO] Adam optimizer — lr=0.0001, trainable params: 356,377
#
# ========================================================================
#   Training Preprocessing System
#   Loss = α·(L_D + λ·L_R) + L_Acc   |  α=10.0, λ=0.001
# ========================================================================
#
# Epoch   1/50 (66.5s)  │  Train  L=6.6955  L_D=0.1492  L_R=214.30  L_Acc=3.0608  Acc=5.00%  │  Val  L=4.7848  L_D=0.0454  L_R=126.43  L_Acc=3.0668  Acc=4.44%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch   2/50 (64.5s)  │  Train  L=4.8277  L_D=0.0307  L_R=145.27  L_Acc=3.0675  Acc=5.56%  │  Val  L=5.3710  L_D=0.0481  L_R=183.47  L_Acc=3.0552  Acc=5.56%
# Epoch   3/50 (68.5s)  │  Train  L=4.5445  L_D=0.0252  L_R=123.19  L_Acc=3.0601  Acc=7.22%  │  Val  L=4.9033  L_D=0.0300  L_R=154.71  L_Acc=3.0565  Acc=5.56%
# Epoch   4/50 (64.8s)  │  Train  L=4.3417  L_D=0.0205  L_R=107.22  L_Acc=3.0650  Acc=6.11%  │  Val  L=4.7685  L_D=0.0266  L_R=143.91  L_Acc=3.0630  Acc=6.11%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch   5/50 (62.9s)  │  Train  L=4.2781  L_D=0.0215  L_R=100.11  L_Acc=3.0618  Acc=7.22%  │  Val  L=4.2947  L_D=0.0174  L_R=105.53  L_Acc=3.0653  Acc=4.44%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch   6/50 (64.7s)  │  Train  L=4.1790  L_D=0.0207  L_R=92.12  L_Acc=3.0514  Acc=6.67%  │  Val  L=4.9071  L_D=0.0279  L_R=157.32  L_Acc=3.0549  Acc=6.11%
# Epoch   7/50 (65.3s)  │  Train  L=4.0973  L_D=0.0182  L_R=84.22  L_Acc=3.0735  Acc=6.11%  │  Val  L=4.1727  L_D=0.0179  L_R=92.46  L_Acc=3.0694  Acc=5.56%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch   8/50 (68.7s)  │  Train  L=4.0103  L_D=0.0175  L_R=77.62  L_Acc=3.0592  Acc=5.56%  │  Val  L=4.7595  L_D=0.0202  L_R=150.10  L_Acc=3.0567  Acc=6.67%
# Epoch   9/50 (67.5s)  │  Train  L=3.9434  L_D=0.0162  L_R=71.65  L_Acc=3.0645  Acc=7.22%  │  Val  L=3.9709  L_D=0.0154  L_R=76.09  L_Acc=3.0562  Acc=6.11%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch  10/50 (64.7s)  │  Train  L=3.8193  L_D=0.0144  L_R=62.48  L_Acc=3.0508  Acc=6.11%  │  Val  L=3.7724  L_D=0.0149  L_R=56.96  L_Acc=3.0535  Acc=6.11%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch  11/50 (67.7s)  │  Train  L=3.8245  L_D=0.0150  L_R=61.31  L_Acc=3.0617  Acc=6.11%  │  Val  L=3.7371  L_D=0.0145  L_R=52.79  L_Acc=3.0645  Acc=6.11%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch  12/50 (67.0s)  │  Train  L=3.8047  L_D=0.0146  L_R=60.13  L_Acc=3.0574  Acc=5.56%  │  Val  L=4.4282  L_D=0.0191  L_R=118.93  L_Acc=3.0478  Acc=5.00%
# Epoch  13/50 (69.0s)  │  Train  L=3.7739  L_D=0.0133  L_R=58.37  L_Acc=3.0569  Acc=5.56%  │  Val  L=3.9160  L_D=0.0183  L_R=67.16  L_Acc=3.0617  Acc=6.11%
# Epoch  14/50 (67.4s)  │  Train  L=3.7095  L_D=0.0150  L_R=51.63  L_Acc=3.0435  Acc=6.67%  │  Val  L=4.0378  L_D=0.0154  L_R=81.79  L_Acc=3.0658  Acc=5.00%
# Epoch  15/50 (65.4s)  │  Train  L=3.7228  L_D=0.0137  L_R=52.34  L_Acc=3.0627  Acc=6.11%  │  Val  L=3.8281  L_D=0.0113  L_R=65.95  L_Acc=3.0559  Acc=6.67%
# Epoch  16/50 (65.3s)  │  Train  L=3.6612  L_D=0.0124  L_R=48.96  L_Acc=3.0477  Acc=7.22%  │  Val  L=3.9490  L_D=0.0136  L_R=74.18  L_Acc=3.0715  Acc=3.89%
# Epoch  17/50 (69.8s)  │  Train  L=3.7330  L_D=0.0157  L_R=52.41  L_Acc=3.0518  Acc=7.22%  │  Val  L=3.9969  L_D=0.0186  L_R=75.40  L_Acc=3.0567  Acc=5.00%
# Epoch  18/50 (73.8s)  │  Train  L=3.6464  L_D=0.0135  L_R=45.62  L_Acc=3.0549  Acc=6.11%  │  Val  L=3.6218  L_D=0.0113  L_R=44.25  L_Acc=3.0666  Acc=4.44%
#   ✓ Saved best checkpoint → /kaggle/working/checkpoints/best_model.pt
# Epoch  19/50 (67.5s)  │  Train  L=3.6564  L_D=0.0124  L_R=48.80  L_Acc=3.0444  Acc=6.67%  │  Val  L=3.8497  L_D=0.0146  L_R=63.76  L_Acc=3.0657  Acc=4.44%
#
# [EARLY STOP] No improvement in L_Acc for 7 epochs.
# [EARLY STOP] Restored best model weights.
#
# [DONE] Final model saved → /kaggle/working/checkpoints/final_model.pt
# [DONE] Best validation loss: 3.6218

# %%
# OR: Train with Kinetics-400 CSV
# !python train.py --dataset-mode kaggle_kinetics400 --kaggle --epochs 50
# Out:
# [INFO] Kaggle environment detected — applying Kaggle defaults
# [INFO] Reduced num_workers to 2 for Kaggle
# [INFO] Using device: cuda
# [INFO] Mode: kaggle_kinetics400 (slug='kinetics-400')
# [INFO] Detected CSV metadata format at: /kaggle/input/datasets/nikiforosvagenas/kinetics-400/test.csv
# [WARN] No video files found — using synthetic clips for pipeline validation. For real training, use a dataset with actual video files.
# Traceback (most recent call last):
#   File "/kaggle/working/repo/train.py", line 604, in <module>
#     main()
#   File "/kaggle/working/repo/train.py", line 477, in main
#     train_dataset, test_dataset, num_classes = build_kaggle_kinetics400_splits(
#                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/repo/dataset.py", line 1228, in build_kaggle_kinetics400_splits
#     base_ds = CSVKinetics400Dataset(
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/repo/dataset.py", line 806, in __init__
#     raise RuntimeError(
# RuntimeError: No samples found in '/kaggle/input/datasets/nikiforosvagenas/kinetics-400/test.csv' (split=None). Check the CSV format and column names.
